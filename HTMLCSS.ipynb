# %% [markdown]
# # HTML/CSS code
# This is the source code I wrote for my [webpage](publish.uwo.ca/~sgolriz).
#
# The following is the main CSS file:

# %%
 div.paragraph {
    margin: 30px;
}

 div.center {
text-align: center
    color: black;
  font-family: "Georgia", Georgia, serif;
font-size: 17px
}
 div.background5{
    background: url(background5.jpg) repeat;
    border: 2px solid black;
}
 div.background4{
    background: url(background4.jpg) repeat;
    border: 2px solid black;
}

div.background3 {
    background: url(background3.jpg) repeat;
    border: 2px solid black;
}
 div.background2 {
    background: url(background2.jpg) repeat;
    border: 2px solid black;
}

 div.background {
    background: url(space.jpg) repeat;
    border: 2px solid black;
}

div.transbox {
    margin: 30px;
    background-color: #ffffff;
    border: 1px solid black;
    opacity: 0.8;
    filter: alpha(opacity=60); /* For IE8 and earlier */
}

div.transbox p {
    margin: 5%;
    font-weight: bold;
    color: #000000;
}


.btn {
  background-color: Transparent
  -webkit-border-radius: 30;
  -moz-border-radius: 30;
  border-radius: 28px;
  text-shadow: 3px 3px 3px grey;
  font-family: Georgia;
  color: black;
  font-size: 18px;
  padding: 6px 11px 6px 18px;
  text-decoration: underline;
}

.btn:hover {
  background: #3cb0fd;
  background-image: -webkit-linear-gradient(top, #3cb0fd, #3498db);
  background-image: -moz-linear-gradient(top, #3cb0fd, #3498db);
  background-image: -ms-linear-gradient(top, #3cb0fd, #3498db);
  background-image: -o-linear-gradient(top, #3cb0fd, #3498db);
  background-image: linear-gradient(to bottom, #3cb0fd, #3498db);
  text-decoration: none;
}

h1 {
    color: black;
    margin-left: 20px;
  font: 400 100px/1.3 'Arizonia', Helvetica, sans-serif;
  text-shadow: 4px 4px 0px rgba(0,0,0,0.1); 
font-size: 50px
}

h2{
    color: black;
    margin-left: 15px;
  font-family:"Times";

}

h3 {
    margin-left: 14px;
    margin-right: 14px;
    color: black;
  font-family:"Times";
font-size: 18px
}

h4 {
    margin-left: 14px;
    margin-right: 14px;
    color: white;
  font-family: "Georgia", Georgia, serif;
font-size: 9px
}

h5 {
    margin-left: 80px;
    margin-right: 50px;
}

p1 {
    margin-left: 14px;
    margin-right: 14px;
    color: black;
  font-family: "Georgia", Georgia, serif;
font-size: 17px
}

p2 {
    color: black;
  font-family: "Georgia", Georgia, serif;
font-size: 15px;
 font-style: italic;
}

ul {
  list-style-type: square;
}

# %% [markdown]
# ##### This is the HTML code for the  [thesis page.](http://publish.uwo.ca/~sgolriz/phd_thesispage.html)

# %%
<!DOCTYPE html>
<html>
<head>
  <title>Sanaz Golriz</title>
</head>
<link rel="stylesheet" type="text/css" href="mystyle.css">
<body>

<div class="background">

<div  align="center"><img src="sanaz.jpg" alt="Ms" style="width:310px;height:300px"></div>


  <div class="transbox">
<link href="http://fonts.googleapis.com/css?family=Arizonia" rel="stylesheet" type="text/css">

<div  align="center">
<button class="btn" onclick="window.location.href='SGOLRIZ_Webpage'" type="submit" target="_blank">Home</button>

<button class="btn" onclick="window.location.href=''" type="submit" target="_blank">Curriculum Vitae</button>

<button class="btn" onclick="window.location.href='phd_thesispage.tex'" type="submit" target="_blank">PhD Thesis</button>

<button class="btn" onclick="window.location.href=''" type="submit" target="_blank">Links</button>
</div>


<h1> PhD Thesis

<button class="btn" onclick="window.location.href='http://ir.lib.uwo.ca/etd/2758'" type="submit" target="_blank">View Online</button>

<button class="btn" onclick="window.location.href='Thesis.pdf'"
type="submit" target="_blank">Download</button>
</h1>

<br><br><br><hr width="500" align="middle">


<div class="paragraph" style="text-align:left; "
><strong><font size="4" color="black">Contact
Info:</font></strong><br><font size="3"
><a href="mailto:sgolriz@alumni.uwo.ca" title=""
>sgolriz@alumni.uwo.ca</font></div>



</div> </div>

</body>
</html>
